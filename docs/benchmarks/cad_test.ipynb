# %% [markdown]
# # Cad test

# %%
from jupyter_cadquery import show, set_defaults
import cadquery as cq

set_defaults(axes=False, grid=False, cad_width=800, height=600)

wp = cq.importers.importStep('oktavian_a.step')
solids = wp.solids().vals()
show(*solids, cad_width=800, height=600)
# Out:
# Overwriting auto display for cadquery Workplane and Shape
# +++++
# CadViewerWidget(anchor=None, aspect_ratio=0.75, cad_width=800, control='trackball', glass=True, height=600, id…
# <div></div>
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[1], line 8
#       6 wp = cq.importers.importStep('oktavian_a.step')
#       7 solids = wp.solids().vals()
# ----> 8 show(*solids, cad_width=800, height=600)
#
# ...
