# %% [markdown]
# # Test cad interactivity

# %%
import cadquery as cq
from jupyter_cadquery import show
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cadquery as cq
# ----> 2 from jupyter_cadquery import show
#
# ModuleNotFoundError: No module named 'jupyter_cadquery'

# %%
# Optional: set viewer defaults
shape = cq.importers.importStep("../../lfs/benchmarks/oktavian/oktavian_a.step")

assembly = cq.Assembly()
assembly.add(shape, name="my_imported_component")

assembly.save(f"oktavian_a.step")
