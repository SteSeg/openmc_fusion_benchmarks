# %% [markdown]
# # Live Code Test Notebook
#
# Click the **▶ Run** button (after activating Thebe) to execute the cell below.

# %% [markdown]
# [![Open in Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/SteSeg/openmc_fusion_benchmarks/HEAD?filepath=docs/benchmarks/oktavian_test.ipynb)

# %%
print("Hello from Thebe!")
