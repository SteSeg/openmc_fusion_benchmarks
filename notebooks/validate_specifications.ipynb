# %% [markdown]
# # Validate Specifications Against Schema

# %% [markdown]
# In *ofb* the benchmark *specifications* are a standardized set of information that should provide all the. To check that they comply with the requirements of this repository it is possible to validate them against the *benchmark_schema* of the repository.
